# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size = 2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size = 2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []
# YOUR CODE HERE

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
  
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 744

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        
        # Append the city information into the city_data list
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_description})
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | mataura
# Processing Record 2 of Set 1 | kytlym
# City not found. Skipping...
# Processing Record 3 of Set 1 | yellowknife
# Processing Record 4 of Set 1 | kavieng
# Processing Record 5 of Set 1 | kargasok
# Processing Record 6 of Set 1 | dosso
# Processing Record 7 of Set 1 | abonnema
# Processing Record 8 of Set 1 | yoichi
# Processing Record 9 of Set 1 | forio
# Processing Record 10 of Set 1 | berlevag
# Processing Record 11 of Set 1 | zhuhai
# Processing Record 12 of Set 1 | albany
# Processing Record 13 of Set 1 | nanortalik
# Processing Record 14 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 15 of Set 1 | rikitea
# Processing Record 16 of Set 1 | thompson
# Processing Record 17 of Set 1 | saint george
# Processing Record 18 of Set 1 | kampot
# Processing Record 19 of Set 1 | pimentel
# Processing Record 20 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 21 of Set 1 | puerto ayora
# Processing Record 22 of Set 1 | saskylakh
# Processing Record 23 of Set 1 | ribeira grande
# Processing Record 24 of Set 1 | pilar
# Processing Record 25 of Set 1 | torbay
# Processing Record 26 of Set 1 | usinsk
# Processing Record 27 of Set 1 | dikson
# Processing Record 28 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 29 of Set 1 | vaini
# Processing Record 30 of Set 1 | marsh harbour
# Processing Record 31 of Set 1 | evensk
# Processing Record 32 of Set 1 | punta arenas
# Processing Record 33 of Set 1 | tura
# Processing Record 34 of Set 1 | saint-philippe
# Processing Record 35 of Set 1 | avarua
# Processing Record 36 of Set 1 | sorland
# Processing Record 37 of Set 1 | zapolyarnyy
# Processing Record 38 of Set 1 | port lincoln
# Processing Record 39 of Set 1 | ekhabi
# Processing Record 40 of Set 1 | medea
# Processing Record 41 of Set 1 | churapcha
# Processing Record 42 of Set 1 | lavrentiya
# Processing Record 43 of Set 1 | araouane
# Processing Record 44 of Set 1 | arraial do cabo
# Processing Record 45 of Set 1 | rajula
# Processing Record 46 of Set 1 | ushuaia
# Processing Record 47 of Set 1 | ocampo
# Processing Record 48 of Set 1 | hithadhoo
# Processing Record 49 of Set 1 | busselton
# Processing Record 50 of Set 1 | bonthe
# Processing Record 1 of Set 2 | hovd
# Processing Record 2 of Set 2 | atuona
# Processing Record 3 of Set 2 | port blair
# Processing Record 4 of Set 2 | castro
# Processing Record 5 of Set 2 | yamethin
# Processing Record 6 of Set 2 | tasiilaq
# Processing Record 7 of Set 2 | port alfred
# Processing Record 8 of Set 2 | santa cruz
# Processing Record 9 of Set 2 | samusu
# City not found. Skipping...
# Processing Record 10 of Set 2 | loikaw
# Processing Record 11 of Set 2 | kamennogorsk
# Processing Record 12 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 13 of Set 2 | guerrero negro
# Processing Record 14 of Set 2 | ajdabiya
# Processing Record 15 of Set 2 | ponta do sol
# Processing Record 16 of Set 2 | cidreira
# Processing Record 17 of Set 2 | talcahuano
# Processing Record 18 of Set 2 | kanigoro
# Processing Record 19 of Set 2 | dingle
# Processing Record 20 of Set 2 | faya
# Processing Record 21 of Set 2 | barrow
# Processing Record 22 of Set 2 | boguchany
# Processing Record 23 of Set 2 | sao joao da barra
# Processing Record 24 of Set 2 | norman wells
# Processing Record 25 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 26 of Set 2 | wageningen
# Processing Record 27 of Set 2 | chapais
# Processing Record 28 of Set 2 | lebu
# Processing Record 29 of Set 2 | new norfolk
# Processing Record 30 of Set 2 | mar del plata
# Processing Record 31 of Set 2 | katsuura
# Processing Record 32 of Set 2 | portland
# Processing Record 33 of Set 2 | hilo
# Processing Record 34 of Set 2 | gizo
# Processing Record 35 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 36 of Set 2 | east london
# Processing Record 37 of Set 2 | khartoum
# Processing Record 38 of Set 2 | nantucket
# Processing Record 39 of Set 2 | ipora
# Processing Record 40 of Set 2 | ansbach
# Processing Record 41 of Set 2 | bethel
# Processing Record 42 of Set 2 | kirovsk
# Processing Record 43 of Set 2 | sisimiut
# Processing Record 44 of Set 2 | sitka
# Processing Record 45 of Set 2 | margate
# Processing Record 46 of Set 2 | durusu
# Processing Record 47 of Set 2 | bharatpur
# Processing Record 48 of Set 2 | provideniya
# Processing Record 49 of Set 2 | hihifo
# City not found. Skipping...
# Processing Record 50 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 1 of Set 3 | talnakh
# Processing Record 2 of Set 3 | baglung
# Processing Record 3 of Set 3 | constitucion
# Processing Record 4 of Set 3 | la ronge
# Processing Record 5 of Set 3 | kapaa
# Processing Record 6 of Set 3 | guilin
# Processing Record 7 of Set 3 | necochea
# Processing Record 8 of Set 3 | qaanaaq
# Processing Record 9 of Set 3 | karratha
# Processing Record 10 of Set 3 | isangel
# Processing Record 11 of Set 3 | airai
# Processing Record 12 of Set 3 | rawson
# Processing Record 13 of Set 3 | doka
# Processing Record 14 of Set 3 | nemuro
# Processing Record 15 of Set 3 | itarema
# Processing Record 16 of Set 3 | teya
# Processing Record 17 of Set 3 | narsaq
# Processing Record 18 of Set 3 | bredasdorp
# Processing Record 19 of Set 3 | linfen
# Processing Record 20 of Set 3 | hami
# Processing Record 21 of Set 3 | port elizabeth
# Processing Record 22 of Set 3 | butaritari
# Processing Record 23 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 24 of Set 3 | roma
# Processing Record 25 of Set 3 | lagoa
# Processing Record 26 of Set 3 | xai-xai
# Processing Record 27 of Set 3 | atambua
# Processing Record 28 of Set 3 | kenai
# Processing Record 29 of Set 3 | esperance
# Processing Record 30 of Set 3 | kodiak
# Processing Record 31 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 32 of Set 3 | hasaki
# Processing Record 33 of Set 3 | pacific grove
# Processing Record 34 of Set 3 | christchurch
# Processing Record 35 of Set 3 | padang
# Processing Record 36 of Set 3 | souillac
# Processing Record 37 of Set 3 | popondetta
# Processing Record 38 of Set 3 | tambovka
# Processing Record 39 of Set 3 | morondava
# Processing Record 40 of Set 3 | ironton
# Processing Record 41 of Set 3 | visby
# Processing Record 42 of Set 3 | qasigiannguit
# Processing Record 43 of Set 3 | bambous virieux
# Processing Record 44 of Set 3 | khatanga
# Processing Record 45 of Set 3 | hermanus
# Processing Record 46 of Set 3 | mayo
# Processing Record 47 of Set 3 | thinadhoo
# Processing Record 48 of Set 3 | camacha
# Processing Record 49 of Set 3 | bluff
# Processing Record 50 of Set 3 | chuy
# Processing Record 1 of Set 4 | deputatskiy
# Processing Record 2 of Set 4 | chengde
# Processing Record 3 of Set 4 | jamestown
# Processing Record 4 of Set 4 | paamiut
# Processing Record 5 of Set 4 | san ramon
# Processing Record 6 of Set 4 | tangi
# Processing Record 7 of Set 4 | suez
# Processing Record 8 of Set 4 | parkes
# Processing Record 9 of Set 4 | sinnamary
# Processing Record 10 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 11 of Set 4 | ancud
# Processing Record 12 of Set 4 | santa catalina sur
# Processing Record 13 of Set 4 | bengkulu
# Processing Record 14 of Set 4 | leningradskiy
# Processing Record 15 of Set 4 | mount isa
# Processing Record 16 of Set 4 | shache
# Processing Record 17 of Set 4 | aswan
# Processing Record 18 of Set 4 | kawana waters
# City not found. Skipping...
# Processing Record 19 of Set 4 | srednekolymsk
# Processing Record 20 of Set 4 | oranjemund
# Processing Record 21 of Set 4 | chokurdakh
# Processing Record 22 of Set 4 | manvi
# Processing Record 23 of Set 4 | yar-sale
# Processing Record 24 of Set 4 | parksville
# Processing Record 25 of Set 4 | funehiki
# Processing Record 26 of Set 4 | springdale
# Processing Record 27 of Set 4 | armeria
# Processing Record 28 of Set 4 | qaqortoq
# Processing Record 29 of Set 4 | palencia
# Processing Record 30 of Set 4 | oktyabrskiy
# Processing Record 31 of Set 4 | iqaluit
# Processing Record 32 of Set 4 | tarakan
# Processing Record 33 of Set 4 | molokovo
# Processing Record 34 of Set 4 | nome
# Processing Record 35 of Set 4 | longyearbyen
# Processing Record 36 of Set 4 | salinopolis
# Processing Record 37 of Set 4 | kuala lipis
# Processing Record 38 of Set 4 | tuktoyaktuk
# Processing Record 39 of Set 4 | kaitangata
# Processing Record 40 of Set 4 | meulaboh
# Processing Record 41 of Set 4 | prince george
# Processing Record 42 of Set 4 | dauphin
# Processing Record 43 of Set 4 | yulara
# Processing Record 44 of Set 4 | ulaanbaatar
# Processing Record 45 of Set 4 | acapulco
# Processing Record 46 of Set 4 | teul
# City not found. Skipping...
# Processing Record 47 of Set 4 | san pedro
# Processing Record 48 of Set 4 | guadalupe y calvo
# Processing Record 49 of Set 4 | caravelas
# Processing Record 50 of Set 4 | gberia fotombu
# Processing Record 1 of Set 5 | hunza
# City not found. Skipping...
# Processing Record 2 of Set 5 | cascais
# Processing Record 3 of Set 5 | corn island
# Processing Record 4 of Set 5 | mount gambier
# Processing Record 5 of Set 5 | salto
# Processing Record 6 of Set 5 | fort-shevchenko
# Processing Record 7 of Set 5 | atbasar
# Processing Record 8 of Set 5 | hobart
# Processing Record 9 of Set 5 | georgetown
# Processing Record 10 of Set 5 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 11 of Set 5 | tual
# Processing Record 12 of Set 5 | chesma
# Processing Record 13 of Set 5 | san patricio
# Processing Record 14 of Set 5 | luderitz
# Processing Record 15 of Set 5 | diffa
# Processing Record 16 of Set 5 | klaksvik
# Processing Record 17 of Set 5 | killarney
# Processing Record 18 of Set 5 | kahului
# Processing Record 19 of Set 5 | tomatlan
# Processing Record 20 of Set 5 | homer
# Processing Record 21 of Set 5 | port macquarie
# Processing Record 22 of Set 5 | conway
# Processing Record 23 of Set 5 | marzuq
# Processing Record 24 of Set 5 | sao filipe
# Processing Record 25 of Set 5 | vanavara
# Processing Record 26 of Set 5 | byron bay
# Processing Record 27 of Set 5 | fare
# Processing Record 28 of Set 5 | severo-kurilsk
# Processing Record 29 of Set 5 | egvekinot
# Processing Record 30 of Set 5 | los llanos de aridane
# Processing Record 31 of Set 5 | port-gentil
# Processing Record 32 of Set 5 | fort nelson
# Processing Record 33 of Set 5 | vila franca do campo
# Processing Record 34 of Set 5 | coahuayana
# Processing Record 35 of Set 5 | bolobo
# Processing Record 36 of Set 5 | lac du bonnet
# Processing Record 37 of Set 5 | talaya
# Processing Record 38 of Set 5 | cumana
# Processing Record 39 of Set 5 | birobidzhan
# Processing Record 40 of Set 5 | tuatapere
# Processing Record 41 of Set 5 | saint-pierre
# Processing Record 42 of Set 5 | fortuna
# Processing Record 43 of Set 5 | vao
# Processing Record 44 of Set 5 | kariba
# Processing Record 45 of Set 5 | sun prairie
# Processing Record 46 of Set 5 | nizhneyansk
# City not found. Skipping...
# Processing Record 47 of Set 5 | sentyabrskiy
# City not found. Skipping...
# Processing Record 48 of Set 5 | taree
# Processing Record 49 of Set 5 | batagay
# Processing Record 50 of Set 5 | sataua
# City not found. Skipping...
# Processing Record 1 of Set 6 | bayonet point
# Processing Record 2 of Set 6 | vardo
# Processing Record 3 of Set 6 | rocha
# Processing Record 4 of Set 6 | petropavlovsk-kamchatskiy
# Processing Record 5 of Set 6 | karabulak
# Processing Record 6 of Set 6 | carnarvon
# Processing Record 7 of Set 6 | port hardy
# Processing Record 8 of Set 6 | kurchum
# Processing Record 9 of Set 6 | nikolskoye
# Processing Record 10 of Set 6 | buraydah
# Processing Record 11 of Set 6 | wates
# Processing Record 12 of Set 6 | kaeo
# Processing Record 13 of Set 6 | gevrai
# Processing Record 14 of Set 6 | vuktyl
# Processing Record 15 of Set 6 | pevek
# Processing Record 16 of Set 6 | komsomolskiy
# Processing Record 17 of Set 6 | cape town
# Processing Record 18 of Set 6 | tezu
# Processing Record 19 of Set 6 | faanui
# Processing Record 20 of Set 6 | grootfontein
# Processing Record 21 of Set 6 | ossora
# Processing Record 22 of Set 6 | kentau
# Processing Record 23 of Set 6 | yongan
# Processing Record 24 of Set 6 | price
# Processing Record 25 of Set 6 | umzimvubu
# City not found. Skipping...
# Processing Record 26 of Set 6 | toora-khem
# Processing Record 27 of Set 6 | vostok
# Processing Record 28 of Set 6 | zyryanka
# Processing Record 29 of Set 6 | avera
# Processing Record 30 of Set 6 | nhulunbuy
# Processing Record 31 of Set 6 | pandamatenga
# Processing Record 32 of Set 6 | barraute
# Processing Record 33 of Set 6 | palana
# Processing Record 34 of Set 6 | aitape
# Processing Record 35 of Set 6 | riyadh
# Processing Record 36 of Set 6 | chara
# Processing Record 37 of Set 6 | hambantota
# Processing Record 38 of Set 6 | alta floresta
# Processing Record 39 of Set 6 | fairbanks
# Processing Record 40 of Set 6 | plettenberg bay
# Processing Record 41 of Set 6 | muroto
# Processing Record 42 of Set 6 | yerofey pavlovich
# Processing Record 43 of Set 6 | puerto baquerizo moreno
# Processing Record 44 of Set 6 | sayyan
# Processing Record 45 of Set 6 | nurota
# Processing Record 46 of Set 6 | westport
# Processing Record 47 of Set 6 | louisbourg
# City not found. Skipping...
# Processing Record 48 of Set 6 | graham
# Processing Record 49 of Set 6 | sangar
# Processing Record 50 of Set 6 | badiraguato
# Processing Record 1 of Set 7 | kut chap
# Processing Record 2 of Set 7 | jinchengjiang
# City not found. Skipping...
# Processing Record 3 of Set 7 | impfondo
# Processing Record 4 of Set 7 | quatre cocos
# Processing Record 5 of Set 7 | urussu
# Processing Record 6 of Set 7 | adavere
# Processing Record 7 of Set 7 | kuche
# City not found. Skipping...
# Processing Record 8 of Set 7 | kosh-agach
# Processing Record 9 of Set 7 | upernavik
# Processing Record 10 of Set 7 | namibe
# Processing Record 11 of Set 7 | geraldton
# Processing Record 12 of Set 7 | benguela
# Processing Record 13 of Set 7 | kushima
# Processing Record 14 of Set 7 | codrington
# Processing Record 15 of Set 7 | kirakira
# Processing Record 16 of Set 7 | mecca
# Processing Record 17 of Set 7 | laguna
# Processing Record 18 of Set 7 | puerto escondido
# Processing Record 19 of Set 7 | sri aman
# Processing Record 20 of Set 7 | saint-francois
# Processing Record 21 of Set 7 | beringovskiy
# Processing Record 22 of Set 7 | duliagaon
# Processing Record 23 of Set 7 | maniitsoq
# Processing Record 24 of Set 7 | saleaula
# City not found. Skipping...
# Processing Record 25 of Set 7 | alta gracia
# Processing Record 26 of Set 7 | udachnyy
# Processing Record 27 of Set 7 | olafsvik
# Processing Record 28 of Set 7 | nola
# Processing Record 29 of Set 7 | belokurikha
# Processing Record 30 of Set 7 | nuristan
# Processing Record 31 of Set 7 | asau
# Processing Record 32 of Set 7 | ahipara
# Processing Record 33 of Set 7 | alencon
# Processing Record 34 of Set 7 | labuhan
# Processing Record 35 of Set 7 | erzin
# Processing Record 36 of Set 7 | yatou
# Processing Record 37 of Set 7 | grand forks
# Processing Record 38 of Set 7 | ulladulla
# Processing Record 39 of Set 7 | montmagny
# Processing Record 40 of Set 7 | batagay-alyta
# Processing Record 41 of Set 7 | waingapu
# Processing Record 42 of Set 7 | lamu
# Processing Record 43 of Set 7 | nuuk
# Processing Record 44 of Set 7 | villa guerrero
# Processing Record 45 of Set 7 | ust-ishim
# Processing Record 46 of Set 7 | otjimbingwe
# Processing Record 47 of Set 7 | naryan-mar
# Processing Record 48 of Set 7 | batticaloa
# Processing Record 49 of Set 7 | concordia
# Processing Record 50 of Set 7 | nayoro
# Processing Record 1 of Set 8 | okhotsk
# Processing Record 2 of Set 8 | palmas bellas
# Processing Record 3 of Set 8 | alofi
# Processing Record 4 of Set 8 | hoshangabad
# Processing Record 5 of Set 8 | arrecife
# Processing Record 6 of Set 8 | adrar
# Processing Record 7 of Set 8 | sinfra
# Processing Record 8 of Set 8 | krasnogvardeyskiy
# Processing Record 9 of Set 8 | gaozhou
# Processing Record 10 of Set 8 | chakwal
# Processing Record 11 of Set 8 | san jose
# Processing Record 12 of Set 8 | fukue
# Processing Record 13 of Set 8 | buala
# Processing Record 14 of Set 8 | kudahuvadhoo
# Processing Record 15 of Set 8 | kolokani
# Processing Record 16 of Set 8 | killybegs
# Processing Record 17 of Set 8 | new albany
# Processing Record 18 of Set 8 | lahaina
# Processing Record 19 of Set 8 | kjollefjord
# Processing Record 20 of Set 8 | tiksi
# Processing Record 21 of Set 8 | deh rawud
# City not found. Skipping...
# Processing Record 22 of Set 8 | aykhal
# Processing Record 23 of Set 8 | beeville
# Processing Record 24 of Set 8 | half moon bay
# Processing Record 25 of Set 8 | kedrovyy
# Processing Record 26 of Set 8 | touho
# Processing Record 27 of Set 8 | puerto pinasco
# City not found. Skipping...
# Processing Record 28 of Set 8 | ostrovnoy
# Processing Record 29 of Set 8 | saint paul
# Processing Record 30 of Set 8 | victoria
# Processing Record 31 of Set 8 | menongue
# Processing Record 32 of Set 8 | tipperary
# Processing Record 33 of Set 8 | sola
# Processing Record 34 of Set 8 | grindavik
# Processing Record 35 of Set 8 | monroe
# Processing Record 36 of Set 8 | makakilo city
# Processing Record 37 of Set 8 | igreja nova
# Processing Record 38 of Set 8 | mizdah
# Processing Record 39 of Set 8 | nobeoka
# Processing Record 40 of Set 8 | kaoma
# Processing Record 41 of Set 8 | cabo san lucas
# Processing Record 42 of Set 8 | angoche
# Processing Record 43 of Set 8 | tahoua
# Processing Record 44 of Set 8 | pinillos
# Processing Record 45 of Set 8 | gondanglegi
# Processing Record 46 of Set 8 | tabat
# Processing Record 47 of Set 8 | otradnyy
# Processing Record 48 of Set 8 | tenango
# Processing Record 49 of Set 8 | sibolga
# Processing Record 50 of Set 8 | ternate
# Processing Record 1 of Set 9 | katherine
# Processing Record 2 of Set 9 | morristown
# Processing Record 3 of Set 9 | saldanha
# Processing Record 4 of Set 9 | innisfail
# Processing Record 5 of Set 9 | gat
# Processing Record 6 of Set 9 | bilibino
# Processing Record 7 of Set 9 | stepnyak
# Processing Record 8 of Set 9 | ostersund
# Processing Record 9 of Set 9 | karamay
# City not found. Skipping...
# Processing Record 10 of Set 9 | coihaique
# Processing Record 11 of Set 9 | clyde river
# Processing Record 12 of Set 9 | lake jackson
# Processing Record 13 of Set 9 | ola
# Processing Record 14 of Set 9 | wenatchee
# Processing Record 15 of Set 9 | opuwo
# Processing Record 16 of Set 9 | nchelenge
# Processing Record 17 of Set 9 | guantanamo
# Processing Record 18 of Set 9 | hamilton
# Processing Record 19 of Set 9 | mayumba
# Processing Record 20 of Set 9 | klyuchi
# Processing Record 21 of Set 9 | athens
# Processing Record 22 of Set 9 | nasirabad
# Processing Record 23 of Set 9 | coruripe
# Processing Record 24 of Set 9 | kovur
# Processing Record 25 of Set 9 | zirandaro
# Processing Record 26 of Set 9 | ucluelet
# Processing Record 27 of Set 9 | abhar
# Processing Record 28 of Set 9 | astoria
# Processing Record 29 of Set 9 | high level
# Processing Record 30 of Set 9 | omsukchan
# Processing Record 31 of Set 9 | hammel
# Processing Record 32 of Set 9 | bangassou
# Processing Record 33 of Set 9 | lebanon
# Processing Record 34 of Set 9 | doha
# Processing Record 35 of Set 9 | bull savanna
# Processing Record 36 of Set 9 | sal rei
# Processing Record 37 of Set 9 | sinkat
# City not found. Skipping...
# Processing Record 38 of Set 9 | sire
# Processing Record 39 of Set 9 | bargal
# City not found. Skipping...
# Processing Record 40 of Set 9 | filingue
# Processing Record 41 of Set 9 | aleksandrov gay
# Processing Record 42 of Set 9 | takoradi
# Processing Record 43 of Set 9 | mogadishu
# Processing Record 44 of Set 9 | itoman
# Processing Record 45 of Set 9 | college
# Processing Record 46 of Set 9 | lamar
# Processing Record 47 of Set 9 | hailar
# Processing Record 48 of Set 9 | lorengau
# Processing Record 49 of Set 9 | sturgeon falls
# Processing Record 50 of Set 9 | kloulklubed
# Processing Record 1 of Set 10 | balyaga
# Processing Record 2 of Set 10 | ayagoz
# Processing Record 3 of Set 10 | kabo
# Processing Record 4 of Set 10 | halalo
# City not found. Skipping...
# Processing Record 5 of Set 10 | mahebourg
# Processing Record 6 of Set 10 | whitianga
# Processing Record 7 of Set 10 | tabina
# Processing Record 8 of Set 10 | isetskoye
# Processing Record 9 of Set 10 | skjervoy
# Processing Record 10 of Set 10 | timbiras
# Processing Record 11 of Set 10 | ambon
# Processing Record 12 of Set 10 | tara
# Processing Record 13 of Set 10 | linqing
# Processing Record 14 of Set 10 | san jeronimo
# Processing Record 15 of Set 10 | taltal
# Processing Record 16 of Set 10 | santa eulalia del rio
# City not found. Skipping...
# Processing Record 17 of Set 10 | cockburn town
# Processing Record 18 of Set 10 | vrangel
# Processing Record 19 of Set 10 | benghazi
# Processing Record 20 of Set 10 | hokitika
# Processing Record 21 of Set 10 | galeana
# Processing Record 22 of Set 10 | akhmeta
# Processing Record 23 of Set 10 | nyurba
# Processing Record 24 of Set 10 | ixtapa
# Processing Record 25 of Set 10 | waw
# Processing Record 26 of Set 10 | kang
# Processing Record 27 of Set 10 | godfrey
# Processing Record 28 of Set 10 | belmonte
# Processing Record 29 of Set 10 | waynesville
# Processing Record 30 of Set 10 | warri
# Processing Record 31 of Set 10 | miyako
# Processing Record 32 of Set 10 | prescott valley
# Processing Record 33 of Set 10 | svetlograd
# Processing Record 34 of Set 10 | bathsheba
# Processing Record 35 of Set 10 | coquimbo
# Processing Record 36 of Set 10 | jilin
# Processing Record 37 of Set 10 | galle
# Processing Record 38 of Set 10 | tidore
# City not found. Skipping...
# Processing Record 39 of Set 10 | porto novo
# Processing Record 40 of Set 10 | shingu
# Processing Record 41 of Set 10 | wajima
# Processing Record 42 of Set 10 | kangaba
# Processing Record 43 of Set 10 | marcona
# City not found. Skipping...
# Processing Record 44 of Set 10 | darnah
# Processing Record 45 of Set 10 | khonuu
# City not found. Skipping...
# Processing Record 46 of Set 10 | miri
# Processing Record 47 of Set 10 | launceston
# Processing Record 48 of Set 10 | miles city
# Processing Record 49 of Set 10 | dhanaula
# Processing Record 50 of Set 10 | kawalu
# Processing Record 1 of Set 11 | megion
# Processing Record 2 of Set 11 | iberia
# Processing Record 3 of Set 11 | alihe
# Processing Record 4 of Set 11 | basoko
# Processing Record 5 of Set 11 | barcelos
# Processing Record 6 of Set 11 | khandbari
# Processing Record 7 of Set 11 | kamenskoye
# City not found. Skipping...
# Processing Record 8 of Set 11 | tumannyy
# City not found. Skipping...
# Processing Record 9 of Set 11 | tazmalt
# Processing Record 10 of Set 11 | lompoc
# Processing Record 11 of Set 11 | gondar
# Processing Record 12 of Set 11 | yunjinghong
# City not found. Skipping...
# Processing Record 13 of Set 11 | marystown
# Processing Record 14 of Set 11 | onega
# Processing Record 15 of Set 11 | urumqi
# Processing Record 16 of Set 11 | otuzco
# Processing Record 17 of Set 11 | rusape
# Processing Record 18 of Set 11 | villa rica
# Processing Record 19 of Set 11 | taga dzong
# City not found. Skipping...
# Processing Record 20 of Set 11 | broome
# Processing Record 21 of Set 11 | vung tau
# Processing Record 22 of Set 11 | kandry
# Processing Record 23 of Set 11 | pisco
# Processing Record 24 of Set 11 | baykit
# Processing Record 25 of Set 11 | bogorodskoye
# Processing Record 26 of Set 11 | mendi
# Processing Record 27 of Set 11 | aasiaat
# Processing Record 28 of Set 11 | kalmunai
# Processing Record 29 of Set 11 | gadag
# Processing Record 30 of Set 11 | cherskiy
# Processing Record 31 of Set 11 | regina
# Processing Record 32 of Set 11 | akdagmadeni
# Processing Record 33 of Set 11 | cayenne
# Processing Record 34 of Set 11 | xicotencatl
# Processing Record 35 of Set 11 | olinda
# Processing Record 36 of Set 11 | belyy yar
# Processing Record 37 of Set 11 | kavaratti
# Processing Record 38 of Set 11 | tahta
# Processing Record 39 of Set 11 | sioux lookout
# Processing Record 40 of Set 11 | gladstone
# Processing Record 41 of Set 11 | husavik
# Processing Record 42 of Set 11 | baturaja
# Processing Record 43 of Set 11 | port keats
# Processing Record 44 of Set 11 | darovskoy
# Processing Record 45 of Set 11 | moyale
# Processing Record 46 of Set 11 | ranong
# Processing Record 47 of Set 11 | nicoya
# Processing Record 48 of Set 11 | hammerfest
# Processing Record 49 of Set 11 | mehndawal
# Processing Record 50 of Set 11 | palabuhanratu
# City not found. Skipping...
# Processing Record 1 of Set 12 | muskegon
# Processing Record 2 of Set 12 | abasolo
# Processing Record 3 of Set 12 | raudeberg
# Processing Record 4 of Set 12 | lolua
# City not found. Skipping...
# Processing Record 5 of Set 12 | japura
# Processing Record 6 of Set 12 | ukiah
# Processing Record 7 of Set 12 | sofiysk
# City not found. Skipping...
# Processing Record 8 of Set 12 | batemans bay
# Processing Record 9 of Set 12 | romanovka
# Processing Record 10 of Set 12 | bud
# Processing Record 11 of Set 12 | elizabeth city
# Processing Record 12 of Set 12 | ballina
# Processing Record 13 of Set 12 | suoyarvi
# Processing Record 14 of Set 12 | bobo dioulasso
# Processing Record 15 of Set 12 | cabungan
# Processing Record 16 of Set 12 | torit
# Processing Record 17 of Set 12 | gravdal
# Processing Record 18 of Set 12 | sabang
# Processing Record 19 of Set 12 | arica
# Processing Record 20 of Set 12 | tha muang
# Processing Record 21 of Set 12 | illapel
# Processing Record 22 of Set 12 | lazaro cardenas
# Processing Record 23 of Set 12 | mumford
# Processing Record 24 of Set 12 | bremervorde
# Processing Record 25 of Set 12 | banda aceh
# Processing Record 26 of Set 12 | carinhanha
# Processing Record 27 of Set 12 | vila velha
# Processing Record 28 of Set 12 | villa carlos paz
# Processing Record 29 of Set 12 | demba
# Processing Record 30 of Set 12 | nioro
# Processing Record 31 of Set 12 | bage
# Processing Record 32 of Set 12 | phrai bung
# City not found. Skipping...
# Processing Record 33 of Set 12 | kingsland
# Processing Record 34 of Set 12 | anicuns
# Processing Record 35 of Set 12 | mabaruma
# Processing Record 36 of Set 12 | tapaua
# City not found. Skipping...
# Processing Record 37 of Set 12 | labutta
# City not found. Skipping...
# Processing Record 38 of Set 12 | guhagar
# Processing Record 39 of Set 12 | zhezkazgan
# Processing Record 40 of Set 12 | eshowe
# Processing Record 41 of Set 12 | cochrane
# Processing Record 42 of Set 12 | slave lake
# Processing Record 43 of Set 12 | maine-soroa
# Processing Record 44 of Set 12 | merauke
# Processing Record 45 of Set 12 | dunedin
# Processing Record 46 of Set 12 | talara
# Processing Record 47 of Set 12 | malakal
# Processing Record 48 of Set 12 | kodyma
# Processing Record 49 of Set 12 | gigmoto
# Processing Record 50 of Set 12 | yeppoon
# Processing Record 1 of Set 13 | kousseri
# Processing Record 2 of Set 13 | inverness
# Processing Record 3 of Set 13 | codajas
# Processing Record 4 of Set 13 | te anau
# Processing Record 5 of Set 13 | kruisfontein
# Processing Record 6 of Set 13 | taoudenni
# Processing Record 7 of Set 13 | achisay
# City not found. Skipping...
# Processing Record 8 of Set 13 | voyvozh
# Processing Record 9 of Set 13 | seddon
# Processing Record 10 of Set 13 | ust-karsk
# Processing Record 11 of Set 13 | poum
# Processing Record 12 of Set 13 | tsabong
# Processing Record 13 of Set 13 | gazni
# City not found. Skipping...
# Processing Record 14 of Set 13 | yangliuqing
# Processing Record 15 of Set 13 | great bend
# Processing Record 16 of Set 13 | mitsamiouli
# Processing Record 17 of Set 13 | mineros
# Processing Record 18 of Set 13 | mbini
# Processing Record 19 of Set 13 | kyenjojo
# Processing Record 20 of Set 13 | oranjestad
# Processing Record 21 of Set 13 | puerto quijarro
# Processing Record 22 of Set 13 | carutapera
# Processing Record 23 of Set 13 | trebisacce
# Processing Record 24 of Set 13 | brandys nad labem-stara boleslav
# Processing Record 25 of Set 13 | henties bay
# Processing Record 26 of Set 13 | sibu
# Processing Record 27 of Set 13 | iskateley
# Processing Record 28 of Set 13 | cairns
# Processing Record 29 of Set 13 | khuzhir
# Processing Record 30 of Set 13 | dutlwe
# Processing Record 31 of Set 13 | chuncheng
# Processing Record 32 of Set 13 | severomuysk
# Processing Record 33 of Set 13 | lata
# Processing Record 34 of Set 13 | ilhabela
# Processing Record 35 of Set 13 | miajadas
# Processing Record 36 of Set 13 | nanakuli
# Processing Record 37 of Set 13 | alice springs
# Processing Record 38 of Set 13 | olga
# Processing Record 39 of Set 13 | pierre
# Processing Record 40 of Set 13 | praia
# Processing Record 41 of Set 13 | vilyuysk
# Processing Record 42 of Set 13 | toliary
# City not found. Skipping...
# Processing Record 43 of Set 13 | northam
# Processing Record 44 of Set 13 | kushiro
# Processing Record 45 of Set 13 | hidalgo
# Processing Record 46 of Set 13 | calatayud
# Processing Record 47 of Set 13 | scottsburgh
# City not found. Skipping...
# Processing Record 48 of Set 13 | cadiz
# Processing Record 49 of Set 13 | sorong
# Processing Record 50 of Set 13 | ulyanovo
# City not found. Skipping...
# Processing Record 1 of Set 14 | hobyo
# Processing Record 2 of Set 14 | kuvshinovo
# Processing Record 3 of Set 14 | pachperwa
# Processing Record 4 of Set 14 | santiago del estero
# Processing Record 5 of Set 14 | cuiluan
# Processing Record 6 of Set 14 | baculin
# Processing Record 7 of Set 14 | koumac
# Processing Record 8 of Set 14 | miranorte
# City not found. Skipping...
# Processing Record 9 of Set 14 | ngukurr
# City not found. Skipping...
# Processing Record 10 of Set 14 | binga
# Processing Record 11 of Set 14 | veraval
# Processing Record 12 of Set 14 | charters towers
# Processing Record 13 of Set 14 | vestmannaeyjar
# Processing Record 14 of Set 14 | callaway
# Processing Record 15 of Set 14 | at-bashi
# Processing Record 16 of Set 14 | jinchang
# Processing Record 17 of Set 14 | charagua
# Processing Record 18 of Set 14 | zhovtneve
# Processing Record 19 of Set 14 | saint-joseph
# Processing Record 20 of Set 14 | poso
# Processing Record 21 of Set 14 | bowen
# Processing Record 22 of Set 14 | capelinha
# Processing Record 23 of Set 14 | lingao
# Processing Record 24 of Set 14 | boyolangu
# Processing Record 25 of Set 14 | grand gaube
# Processing Record 26 of Set 14 | ust-ilimsk
# Processing Record 27 of Set 14 | staraya poltavka
# Processing Record 28 of Set 14 | aflao
# Processing Record 29 of Set 14 | north bend
# Processing Record 30 of Set 14 | cape coast
# Processing Record 31 of Set 14 | gornopravdinsk
# Processing Record 32 of Set 14 | keelung
# Processing Record 33 of Set 14 | nalbandyan
# Processing Record 34 of Set 14 | kijang
# Processing Record 35 of Set 14 | hvammstangi
# City not found. Skipping...
# Processing Record 36 of Set 14 | zambezi
# Processing Record 37 of Set 14 | barguzin
# Processing Record 38 of Set 14 | sampit
# Processing Record 39 of Set 14 | samalaeulu
# City not found. Skipping...
# Processing Record 40 of Set 14 | hoquiam
# Processing Record 41 of Set 14 | muscat
# Processing Record 42 of Set 14 | fereydun kenar
# Processing Record 43 of Set 14 | jackson
# Processing Record 44 of Set 14 | san lorenzo
# Processing Record 45 of Set 14 | tasbuget
# City not found. Skipping...
# Processing Record 46 of Set 14 | nuevo laredo
# Processing Record 47 of Set 14 | sassandra
# Processing Record 48 of Set 14 | pentalofos
# Processing Record 49 of Set 14 | obera
# Processing Record 50 of Set 14 | anderson
# Processing Record 1 of Set 15 | umm lajj
# Processing Record 2 of Set 15 | den helder
# Processing Record 3 of Set 15 | hede
# Processing Record 4 of Set 15 | umm durman
# City not found. Skipping...
# Processing Record 5 of Set 15 | zhangjiakou
# Processing Record 6 of Set 15 | mao
# Processing Record 7 of Set 15 | nova serrana
# Processing Record 8 of Set 15 | golden
# Processing Record 9 of Set 15 | nouadhibou
# Processing Record 10 of Set 15 | richards bay
# Processing Record 11 of Set 15 | goure
# Processing Record 12 of Set 15 | palmer
# Processing Record 13 of Set 15 | nishihara
# Processing Record 14 of Set 15 | agirish
# Processing Record 15 of Set 15 | inhambane
# Processing Record 16 of Set 15 | bakani
# Processing Record 17 of Set 15 | columbus
# Processing Record 18 of Set 15 | ruteng
# Processing Record 19 of Set 15 | sompeta
# Processing Record 20 of Set 15 | san quintin
# Processing Record 21 of Set 15 | muros
# Processing Record 22 of Set 15 | songea
# Processing Record 23 of Set 15 | wattegama
# Processing Record 24 of Set 15 | amboasary
# Processing Record 25 of Set 15 | basco
# Processing Record 26 of Set 15 | smithers
# Processing Record 27 of Set 15 | alyangula
# Processing Record 28 of Set 15 | atlantic beach
# Processing Record 29 of Set 15 | esso
# Processing Record 30 of Set 15 | tecolutla
# Processing Record 31 of Set 15 | mbala
# Processing Record 32 of Set 15 | krasnoselkup
# Processing Record 33 of Set 15 | artyk
# City not found. Skipping...
# Processing Record 34 of Set 15 | along
# Processing Record 35 of Set 15 | dali
# Processing Record 36 of Set 15 | barbar
# City not found. Skipping...
# Processing Record 37 of Set 15 | poya
# Processing Record 38 of Set 15 | palamos
# Processing Record 39 of Set 15 | malatya
# Processing Record 40 of Set 15 | giresun
# Processing Record 41 of Set 15 | russell
# Processing Record 42 of Set 15 | rantepao
# Processing Record 43 of Set 15 | biltine
# Processing Record 44 of Set 15 | liberal
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 686

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#           City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0      Mataura -46.1927  168.8643     54.07        98         100        3.40
# 1  Yellowknife  62.4560 -114.3525    -32.28        75          75        6.91
# 2      Kavieng  -2.5744  150.7967     83.53        74         100       10.69
# 3     Kargasok  59.0556   80.8572      2.39        80         100       15.70
# 4        Dosso  13.0490    3.1937     66.36        27          70       15.66
# 5     Abonnema   4.7084    6.7931     68.29        68          43        4.81
# 6       Yoichi  43.2039  140.7703     34.75        93         100        6.80
# 7        Forio  40.7342   13.8646     57.81        92          14        1.99
# 8     Berlevag  70.8578   29.0864     24.80        80          75        9.22
# 9       Zhuhai  22.2769  113.5678     72.86        45           0        6.91
#
#   Country Current Description
# 0      NZ     overcast clouds
# 1      CA          light snow
# 2      PG     overcast clouds
# 3      RU     overcast clouds
# 4      NE       broken clouds
# 5      NG    scattered clouds
# 6      JP          light snow
# 7      IT          few clouds
# 8      NO          light snow
# 9      CN           clear sky

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Country', 'Current Description'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
new_column_order = ["City", "Country", "Lat","Lng","Max Temp","Humidity","Cloudiness","Wind Speed","Current Description"]

# Recreate the DataFrame by using the new column order
city_data_df = city_data_df[new_column_order]

# Display sample data
city_data_df.head(10)
# Out:
#           City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      Mataura      NZ -46.1927  168.8643     54.07        98         100
# 1  Yellowknife      CA  62.4560 -114.3525    -32.28        75          75
# 2      Kavieng      PG  -2.5744  150.7967     83.53        74         100
# 3     Kargasok      RU  59.0556   80.8572      2.39        80         100
# 4        Dosso      NE  13.0490    3.1937     66.36        27          70
# 5     Abonnema      NG   4.7084    6.7931     68.29        68          43
# 6       Yoichi      JP  43.2039  140.7703     34.75        93         100
# 7        Forio      IT  40.7342   13.8646     57.81        92          14
# 8     Berlevag      NO  70.8578   29.0864     24.80        80          75
# 9       Zhuhai      CN  22.2769  113.5678     72.86        45           0
#
#    Wind Speed Current Description
# 0        3.40     overcast clouds
# 1        6.91          light snow
# 2       10.69     overcast clouds
# 3       15.70     overcast clouds
# 4       15.66       broken clouds
# 5        4.81    scattered clouds
# 6        6.80          light snow
# 7        1.99          few clouds
# 8        9.22          light snow
# 9        6.91           clear sky

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_data_file = "./WeatherPy_Database.csv"

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output_data_file, index_label="City_ID")
